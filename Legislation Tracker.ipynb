# %%
# Federal, State, County legislation
# Scrape all legislation, show all bills
# Filter for passed vs proposed
# Use AI to guess which ones might be relevant for the Ward, show as separate column
# Click "Summarize" and write a report
